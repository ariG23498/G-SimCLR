# %% [markdown]
# <a href="https://colab.research.google.com/github/ariG23498/SimCLR_PseudoLabel/blob/master/10_Per_Linear_Evaluation_Imagenet_Subset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Initial setup

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
# !nvidia-smi
# Out:
# Thu Aug 20 04:36:36 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Restoring model weights from GCS Bucket

# %%
# !wget https://storage.googleapis.com/resnet-simclr-pseudo-labels/resnet_simclr_modified_ae.h5
# Out:
# --2020-08-20 04:36:53--  https://storage.googleapis.com/resnet-simclr-pseudo-labels/resnet_simclr_modified_ae.h5
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.20.128, 74.125.142.128, 74.125.195.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.20.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96848264 (92M) [application/octet-stream]
# Saving to: ‘resnet_simclr_modified_ae.h5’
#
# resnet_simclr_modif 100%[===================>]  92.36M   153MB/s    in 0.6s
#
# 2020-08-20 04:36:54 (153 MB/s) - ‘resnet_simclr_modified_ae.h5’ saved [96848264/96848264]

# %%
# Other imports
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import matplotlib.pyplot as plt
from imutils import paths
from tqdm import tqdm
import tensorflow as tf
import seaborn as sns
import numpy as np
import cv2

# Random seed fixation
tf.random.set_seed(666)
np.random.seed(666)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Dataset gathering and preparation

# %%
# Gather dataset
# !git clone https://github.com/thunderInfy/imagenet-5-categories
# Out:
# fatal: destination path 'imagenet-5-categories' already exists and is not an empty directory.

# %%
# Train and test image paths
train_images = list(paths.list_images("imagenet-5-categories/train"))
test_images = list(paths.list_images("imagenet-5-categories/test"))
print(len(train_images), len(test_images))
# Out:
# 1250 250

# %%
# 10% of the dataset
train_images_10 = np.random.choice(train_images, len(train_images)//10)
len(train_images_10)
# Out:
# 125

# %%
def prepare_images(image_paths):
    images = []
    labels = []

    for image in tqdm(image_paths):
        image_pixels = plt.imread(image)
        image_pixels = cv2.resize(image_pixels, (224, 224))
        image_pixels = image_pixels/255.

        label = image.split("/")[2].split("_")[0]

        images.append(image_pixels)
        labels.append(label)

    images = np.array(images)
    labels = np.array(labels)

    print(images.shape, labels.shape)

    return images, labels

# %%
X_train, y_train = prepare_images(train_images_10)
X_test, y_test = prepare_images(test_images)
# Out:
# 100%|██████████| 125/125 [00:00<00:00, 214.59it/s]
#   6%|▌         | 15/250 [00:00<00:01, 146.29it/s]
# (125, 224, 224, 3) (125,)
# 100%|██████████| 250/250 [00:01<00:00, 226.27it/s]
# (250, 224, 224, 3) (250,)

# %%
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)

# %% [markdown]
# ## Utilities

# %%
# Architecture utils
def get_resnet_simclr(hidden_1, hidden_2, hidden_3):
    base_model = tf.keras.applications.ResNet50(include_top=False, weights=None, input_shape=(224, 224, 3))
    base_model.trainabe = True
    inputs = Input((224, 224, 3))
    h = base_model(inputs, training=True)
    h = GlobalAveragePooling2D()(h)

    projection_1 = Dense(hidden_1)(h)
    projection_1 = Activation("relu")(projection_1)
    projection_2 = Dense(hidden_2)(projection_1)
    projection_2 = Activation("relu")(projection_2)
    projection_3 = Dense(hidden_3)(projection_2)

    resnet_simclr = Model(inputs, projection_3)

    return resnet_simclr

# %%
resnet_simclr = get_resnet_simclr(256, 128, 50)
resnet_simclr.load_weights('resnet_simclr_modified_ae.h5')
resnet_simclr.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               524544
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                6450
# =================================================================
# Total params: 24,151,602
# Trainable params: 24,098,482
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
def plot_training(H):
	with plt.xkcd():
		plt.plot(H.history["loss"], label="train_loss")
		plt.plot(H.history["val_loss"], label="val_loss")
		plt.plot(H.history["accuracy"], label="train_acc")
		plt.plot(H.history["val_accuracy"], label="val_acc")
		plt.title("Training Loss and Accuracy")
		plt.xlabel("Epoch #")
		plt.ylabel("Loss/Accuracy")
		plt.legend(loc="lower left")
		plt.show()

# %%
def get_linear_model(features):
    linear_model = Sequential([Dense(5, input_shape=(features, ), activation="softmax")])
    return linear_model

# %% [markdown]
# ## Evaluation

# %%
# Encoder model with non-linear projections
projection = Model(resnet_simclr.input, resnet_simclr.layers[-2].output)

# Extract train and test features
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)

print(train_features.shape, test_features.shape)
# Out:
# (125, 128) (250, 128)

# %%
# Early Stopping to prevent overfitting
es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=2, verbose=2, restore_best_weights=True)

# %%
# Linear model
linear_model = get_linear_model(128)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=100,
                 callbacks=[es])
plot_training(history)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 50ms/step - loss: 6.6477 - accuracy: 0.1200 - val_loss: 7.1315 - val_accuracy: 0.1120
# Epoch 2/100
# 2/2 [==============================] - 0s 10ms/step - loss: 6.1894 - accuracy: 0.1200 - val_loss: 6.6483 - val_accuracy: 0.1280
# Epoch 3/100
# 2/2 [==============================] - 0s 10ms/step - loss: 5.7675 - accuracy: 0.1280 - val_loss: 6.1960 - val_accuracy: 0.1480
# Epoch 4/100
# 2/2 [==============================] - 0s 10ms/step - loss: 5.3719 - accuracy: 0.1360 - val_loss: 5.7635 - val_accuracy: 0.1760
# Epoch 5/100
# 2/2 [==============================] - 0s 10ms/step - loss: 5.0100 - accuracy: 0.1520 - val_loss: 5.3506 - val_accuracy: 0.1880
# Epoch 6/100
# 2/2 [==============================] - 0s 10ms/step - loss: 4.6747 - accuracy: 0.1520 - val_loss: 4.9622 - val_accuracy: 0.2040
# Epoch 7/100
# 2/2 [==============================] - 0s 10ms/step - loss: 4.3423 - accuracy: 0.1600 - val_loss: 4.6081 - val_accuracy: 0.2080
# Epoch 8/100
# 2/2 [==============================] - 0s 10ms/step - loss: 4.0454 - accuracy: 0.1680 - val_loss: 4.2923 - val_accuracy: 0.2200
# Epoch 9/100
# 2/2 [==============================] - 0s 10ms/step - loss: 3.7670 - accuracy: 0.1680 - val_loss: 4.0187 - val_accuracy: 0.2480
# Epoch 10/100
# 2/2 [==============================] - 0s 10ms/step - loss: 3.5520 - accuracy: 0.1680 - val_loss: 3.7711 - val_accuracy: 0.2680
# Epoch 11/100
# 2/2 [==============================] - 0s 10ms/step - loss: 3.3338 - accuracy: 0.1760 - val_loss: 3.5524 - val_accuracy: 0.2920
# Epoch 12/100
# 2/2 [==============================] - 0s 10ms/step - loss: 3.1583 - accuracy: 0.1760 - val_loss: 3.3469 - val_accuracy: 0.3040
# Epoch 13/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.9666 - accuracy: 0.2000 - val_loss: 3.1535 - val_accuracy: 0.3200
# Epoch 14/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.7906 - accuracy: 0.2240 - val_loss: 2.9670 - val_accuracy: 0.3280
# Epoch 15/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.6216 - accuracy: 0.2640 - val_loss: 2.7925 - val_accuracy: 0.3240
# Epoch 16/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.4676 - accuracy: 0.2800 - val_loss: 2.6269 - val_accuracy: 0.3200
# Epoch 17/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.3091 - accuracy: 0.2960 - val_loss: 2.4802 - val_accuracy: 0.3240
# Epoch 18/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.1927 - accuracy: 0.3120 - val_loss: 2.3482 - val_accuracy: 0.3440
# Epoch 19/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0776 - accuracy: 0.3280 - val_loss: 2.2379 - val_accuracy: 0.3600
# Epoch 20/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9973 - accuracy: 0.3280 - val_loss: 2.1386 - val_accuracy: 0.3600
# Epoch 21/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.9269 - accuracy: 0.3680 - val_loss: 2.0581 - val_accuracy: 0.3760
# Epoch 22/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.8702 - accuracy: 0.3760 - val_loss: 1.9883 - val_accuracy: 0.3760
# Epoch 23/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.8171 - accuracy: 0.3840 - val_loss: 1.9315 - val_accuracy: 0.3880
# Epoch 24/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.7739 - accuracy: 0.4080 - val_loss: 1.8829 - val_accuracy: 0.3880
# Epoch 25/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.7314 - accuracy: 0.4000 - val_loss: 1.8369 - val_accuracy: 0.4080
# Epoch 26/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6892 - accuracy: 0.4000 - val_loss: 1.7972 - val_accuracy: 0.4360
# Epoch 27/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6519 - accuracy: 0.4240 - val_loss: 1.7652 - val_accuracy: 0.4440
# Epoch 28/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6100 - accuracy: 0.4320 - val_loss: 1.7376 - val_accuracy: 0.4440
# Epoch 29/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5759 - accuracy: 0.4560 - val_loss: 1.7173 - val_accuracy: 0.4320
# Epoch 30/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5486 - accuracy: 0.4800 - val_loss: 1.6970 - val_accuracy: 0.4320
# Epoch 31/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.5214 - accuracy: 0.4960 - val_loss: 1.6805 - val_accuracy: 0.4240
# Epoch 32/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4987 - accuracy: 0.5040 - val_loss: 1.6646 - val_accuracy: 0.4160
# Epoch 33/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4773 - accuracy: 0.5280 - val_loss: 1.6524 - val_accuracy: 0.4200
# Epoch 34/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4607 - accuracy: 0.5200 - val_loss: 1.6382 - val_accuracy: 0.4120
# Epoch 35/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4427 - accuracy: 0.5440 - val_loss: 1.6253 - val_accuracy: 0.4160
# Epoch 36/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4284 - accuracy: 0.5520 - val_loss: 1.6176 - val_accuracy: 0.4160
# Epoch 37/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4100 - accuracy: 0.5680 - val_loss: 1.6063 - val_accuracy: 0.4200
# Epoch 38/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.3962 - accuracy: 0.5520 - val_loss: 1.5939 - val_accuracy: 0.4200
# Epoch 39/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3823 - accuracy: 0.5520 - val_loss: 1.5837 - val_accuracy: 0.4240
# Epoch 40/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.3698 - accuracy: 0.5600 - val_loss: 1.5761 - val_accuracy: 0.4200
# Epoch 41/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3601 - accuracy: 0.5520 - val_loss: 1.5683 - val_accuracy: 0.4200
# Epoch 42/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3498 - accuracy: 0.5440 - val_loss: 1.5647 - val_accuracy: 0.4160
# Epoch 43/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3392 - accuracy: 0.5520 - val_loss: 1.5584 - val_accuracy: 0.4160
# Epoch 44/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3305 - accuracy: 0.5520 - val_loss: 1.5527 - val_accuracy: 0.4200
# Epoch 45/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3215 - accuracy: 0.5600 - val_loss: 1.5510 - val_accuracy: 0.4160
# Epoch 46/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3126 - accuracy: 0.5680 - val_loss: 1.5477 - val_accuracy: 0.4120
# Epoch 47/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3056 - accuracy: 0.5680 - val_loss: 1.5466 - val_accuracy: 0.4120
# Epoch 48/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2988 - accuracy: 0.5680 - val_loss: 1.5428 - val_accuracy: 0.4080
# Epoch 49/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2916 - accuracy: 0.5680 - val_loss: 1.5383 - val_accuracy: 0.4080
# Epoch 50/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2857 - accuracy: 0.5520 - val_loss: 1.5365 - val_accuracy: 0.4200
# Epoch 51/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2790 - accuracy: 0.5680 - val_loss: 1.5355 - val_accuracy: 0.4240
# Epoch 52/100
# 2/2 [==============================] - 0s 16ms/step - loss: 1.2736 - accuracy: 0.5680 - val_loss: 1.5311 - val_accuracy: 0.4160
# Epoch 53/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2683 - accuracy: 0.5600 - val_loss: 1.5280 - val_accuracy: 0.4120
# Epoch 54/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2648 - accuracy: 0.5600 - val_loss: 1.5284 - val_accuracy: 0.4120
# Epoch 55/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2578 - accuracy: 0.5760 - val_loss: 1.5258 - val_accuracy: 0.4080
# Epoch 56/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2548 - accuracy: 0.5840 - val_loss: 1.5241 - val_accuracy: 0.3960
# Epoch 57/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2503 - accuracy: 0.5840 - val_loss: 1.5213 - val_accuracy: 0.4040
# Epoch 58/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2464 - accuracy: 0.5760 - val_loss: 1.5221 - val_accuracy: 0.4000
# Epoch 59/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2420 - accuracy: 0.5680 - val_loss: 1.5183 - val_accuracy: 0.3960
# Epoch 60/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2405 - accuracy: 0.5840 - val_loss: 1.5135 - val_accuracy: 0.4160
# Epoch 61/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2347 - accuracy: 0.5760 - val_loss: 1.5125 - val_accuracy: 0.4120
# Epoch 62/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2311 - accuracy: 0.5920 - val_loss: 1.5154 - val_accuracy: 0.4000
# Epoch 63/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1467 - accuracy: 0.5312Restoring model weights from the end of the best epoch.
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2274 - accuracy: 0.5760 - val_loss: 1.5176 - val_accuracy: 0.3840
# Epoch 00063: early stopping

# %%
# Encoder model with lesser non-linearity
projection = Model(resnet_simclr.input, resnet_simclr.layers[-4].output)

# Extract train and test features
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)

print(train_features.shape, test_features.shape)
# Out:
# (125, 256) (250, 256)

# %%
linear_model = get_linear_model(256)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es])
plot_training(history)
# Out:
# Epoch 1/35
# 2/2 [==============================] - 0s 51ms/step - loss: 7.1784 - accuracy: 0.2000 - val_loss: 5.8737 - val_accuracy: 0.2040
# Epoch 2/35
# 2/2 [==============================] - 0s 10ms/step - loss: 6.0935 - accuracy: 0.2000 - val_loss: 5.0538 - val_accuracy: 0.2440
# Epoch 3/35
# 2/2 [==============================] - 0s 10ms/step - loss: 5.2377 - accuracy: 0.2480 - val_loss: 4.4268 - val_accuracy: 0.2400
# Epoch 4/35
# 2/2 [==============================] - 0s 10ms/step - loss: 4.5733 - accuracy: 0.2000 - val_loss: 3.9293 - val_accuracy: 0.2040
# Epoch 5/35
# 2/2 [==============================] - 0s 10ms/step - loss: 3.9743 - accuracy: 0.1840 - val_loss: 3.5103 - val_accuracy: 0.1560
# Epoch 6/35
# 2/2 [==============================] - 0s 11ms/step - loss: 3.5212 - accuracy: 0.1920 - val_loss: 3.1338 - val_accuracy: 0.1520
# Epoch 7/35
# 2/2 [==============================] - 0s 10ms/step - loss: 3.0696 - accuracy: 0.2160 - val_loss: 2.8437 - val_accuracy: 0.1400
# Epoch 8/35
# 2/2 [==============================] - 0s 10ms/step - loss: 2.7947 - accuracy: 0.1920 - val_loss: 2.6973 - val_accuracy: 0.1600
# Epoch 9/35
# 2/2 [==============================] - 0s 10ms/step - loss: 2.6734 - accuracy: 0.1680 - val_loss: 2.7115 - val_accuracy: 0.1800
# Epoch 10/35
# 1/2 [==============>...............] - ETA: 0s - loss: 2.7069 - accuracy: 0.1875Restoring model weights from the end of the best epoch.
# 2/2 [==============================] - 0s 10ms/step - loss: 2.6212 - accuracy: 0.1920 - val_loss: 2.7412 - val_accuracy: 0.2080
# Epoch 00010: early stopping

# %%
# Encoder model with no projection
projection = Model(resnet_simclr.input, resnet_simclr.layers[-6].output)

# Extract train and test features
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)

print(train_features.shape, test_features.shape)
# Out:
# (125, 2048) (250, 2048)

# %%
linear_model = get_linear_model(2048)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es])
plot_training(history)
# Out:
# Epoch 1/35
# 2/2 [==============================] - 0s 57ms/step - loss: 2.1317 - accuracy: 0.2000 - val_loss: 2.0591 - val_accuracy: 0.2160
# Epoch 2/35
# 2/2 [==============================] - 0s 12ms/step - loss: 1.9669 - accuracy: 0.2160 - val_loss: 1.8965 - val_accuracy: 0.3640
# Epoch 3/35
# 2/2 [==============================] - 0s 12ms/step - loss: 1.6933 - accuracy: 0.4000 - val_loss: 1.8207 - val_accuracy: 0.3160
# Epoch 4/35
# 2/2 [==============================] - 0s 12ms/step - loss: 1.4511 - accuracy: 0.4800 - val_loss: 1.4132 - val_accuracy: 0.3840
# Epoch 5/35
# 2/2 [==============================] - 0s 12ms/step - loss: 1.2366 - accuracy: 0.5040 - val_loss: 1.3662 - val_accuracy: 0.4720
# Epoch 6/35
# 2/2 [==============================] - 0s 13ms/step - loss: 1.3469 - accuracy: 0.4400 - val_loss: 1.3474 - val_accuracy: 0.4720
# Epoch 7/35
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2575 - accuracy: 0.5280 - val_loss: 1.4223 - val_accuracy: 0.4320
# Epoch 8/35
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1070 - accuracy: 0.5469Restoring model weights from the end of the best epoch.
# 2/2 [==============================] - 0s 12ms/step - loss: 1.2032 - accuracy: 0.5600 - val_loss: 1.5248 - val_accuracy: 0.3880
# Epoch 00008: early stopping
